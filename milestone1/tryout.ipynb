# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
# read a video
video_path = os.path.join('vids', 'welad rizk.mp4')
video = cv2.VideoCapture(video_path)
video.set(cv2.CAP_PROP_FPS, 30)
video.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
video.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)

# read the first frame
ret, frame = video.read()
if not ret:
    print("Failed to read video")
    exit()
# convert to grayscale
gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
# apply Gaussian blur
gray = cv2.GaussianBlur(gray, (5, 5), 0)
# display the result

plt.imshow(gray, cmap='gray')
plt.title("Grayscale Frame")
plt.axis('off')
plt.show()

# %%
import cv2
import os

def extract_frames(video_path, save_dir, fps_limit=10):
    cap = cv2.VideoCapture(video_path)
    video_fps = cap.get(cv2.CAP_PROP_FPS)
    frame_interval = int(video_fps / fps_limit)
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    count = 0
    saved = 0
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        if count % frame_interval == 0:
            resized = cv2.resize(frame, (640, 480))
            cv2.imwrite(os.path.join(save_dir, f'frame_{saved:04}.png'), resized)
            saved += 1
        count += 1
    cap.release()

# %%
extract_frames("./vids/x-meraty.mp4", "./output_frames/x-meraty", fps_limit=10)

# %%
extract_frames("./vids/2rd_el_nefak.mp4", "./output_frames/2rd_el_nefak", fps_limit=10)

# %%
import cv2

def detect_face(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    detector = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    faces = detector.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)
    return len(faces), faces

# %%
detect_face("./output_frames/2rd_el_nefak/frame_0107.png")
# Out:
# (4,
#  array([[214, 376,  70,  70],
#         [345,  68, 218, 218],
#         [366, 287,  79,  79],
#         [157, 131, 152, 152]]))

# %%
# !pip install --upgrade ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (8.2.88)
# Collecting ultralytics
#   Downloading ultralytics-8.3.98-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from ultralytics) (1.24.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from ultralytics) (10.0.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from ultralytics) (1.10.0)
# Requirement already satisfied: torch>=1.8.0 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from ultralytics) (2.4.1+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from ultralytics) (0.19.1)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: psutil in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from ultralytics) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from ultralytics) (2.0.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (6.1.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from requests>=2.23.0->ultralytics) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from requests>=2.23.0->ultralytics) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from torch>=1.8.0->ultralytics) (2023.12.2)
# Requirement already satisfied: colorama in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.0->ultralytics) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading ultralytics-8.3.98-py3-none-any.whl (949 kB)
#    ---------------------------------------- 0.0/950.0 kB ? eta -:--:--
#    --------------------------------- ------ 786.4/950.0 kB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 950.0/950.0 kB 5.5 MB/s eta 0:00:00
# Installing collected packages: ultralytics
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.2.88
#     Uninstalling ultralytics-8.2.88:
#       Successfully uninstalled ultralytics-8.2.88
# Successfully installed ultralytics-8.3.98
# WARNING: Ignoring invalid distribution -ltralytics (c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages)
# WARNING: Error parsing dependencies of markdown-katex: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     Markdown (>=3.0<3.3) ; python_version < "3.6"
#              ~~~~~~^
# WARNING: Ignoring invalid distribution -ltralytics (c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages)
# WARNING: Ignoring invalid distribution -ltralytics (c:\users\001\anaconda3\envs\pytorch-env\lib\site-packages)

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

def count_faces_yolo(image_path, model_path='yolo11s.pt', conf_threshold=0.5, show=False):
    """
    Detect and count faces in an image using YOLOv8.

    Parameters:
        image_path (str): Path to the input image.
        model_path (str): Path to the YOLOv8 face detection model.
        conf_threshold (float): Confidence threshold for detections.
        show (bool): If True, displays the image with detected faces.

    Returns:
        int: Number of faces detected.
        list: List of bounding boxes [x1, y1, x2, y2] for each face.
    """
    model = YOLO(model_path)
    model.to('cpu')

    results = model(image_path, conf=conf_threshold)

    boxes = results[0].boxes.xyxy.cpu().numpy().astype(int)

    if show:
        img = cv2.imread(image_path)

        for box in boxes:
            x1, y1, x2, y2 = box
            cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)

        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.axis('off')

    return len(boxes), boxes.tolist()

image_path = './output_frames/2rd_el_nefak/frame_0107.png'
num_faces, face_boxes = count_faces_yolo(image_path, show=True)
print(f"Number of faces detected: {num_faces}")
# Out:
# image 1/1 c:\Users\001\OneDrive\Desktop\GUC\semester 10\dlcv\DLCV-Project\output_frames\2rd_el_nefak\frame_0107.png: 480x640 2 persons, 159.6ms
# Speed: 1.2ms preprocess, 159.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Number of faces detected: 2

# %%
image_path = './output_frames/x-meraty/frame_0020.png'
num_faces, face_boxes = count_faces_yolo(image_path, show=True)
print(f"Number of faces detected: {num_faces}")
# Out:
# image 1/1 c:\Users\001\OneDrive\Desktop\GUC\semester 10\dlcv\DLCV-Project\output_frames\x-meraty\frame_0020.png: 480x640 1 person, 174.6ms
# Speed: 1.2ms preprocess, 174.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Number of faces detected: 1
